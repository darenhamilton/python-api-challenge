# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [raw]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
lat_lngs

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print(json.dumps(requests.get(query_url + 'lompoc').json(), indent=3))
# Out:
# {
#    "coord": {
#       "lon": -120.46,
#       "lat": 34.64
#    },
#    "weather": [
#       {
#          "id": 800,
#          "main": "Clear",
#          "description": "clear sky",
#          "icon": "01d"
#       }
#    ],
#    "base": "stations",
#    "main": {
#       "temp": 21.21,
#       "feels_like": 17.84,
#       "temp_min": 19,
#       "temp_max": 23.33,
#       "pressure": 1014,
#       "humidity": 60
#    },
#    "visibility": 10000,
#    "wind": {
#       "speed": 6.2,
#       "deg": 250,
#       "gust": 8.7
#    },
#    "clouds": {
#       "all": 0
#    },
#    "dt": 1596323348,
#    "sys": {
#       "type": 1,
#       "id": 4747,
#       "country": "US",
#       "sunrise": 1596287544,
#       "sunset": 1596337424
#    },
#    "timezone": -25200,
#    "id": 5367788,
#    "name": "Lompoc",
#    "cod": 200
# }

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={weather_api_key}&units={units}&q="
# print(jason.dumps(response, indent=4))
name = []
lat = []
long = []
temp_max = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

#loop through cities
for city in cities:
    response = requests.get(query_url + city).json()    
    print(f"The name infomation recieved is: {city}")
    try:
        name.append(response["name"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        temp_max.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])

#         print(f"The name infomation recieved is: {city}")
       
       
    except:
        print('no city data')
        pass
# Out:
# The name infomation recieved is: cidreira
# The name infomation recieved is: bokspits
# no city data
# The name infomation recieved is: lebu
# The name infomation recieved is: rikitea
# The name infomation recieved is: coihueco
# The name infomation recieved is: ushuaia
# The name infomation recieved is: busselton
# The name infomation recieved is: kloulklubed
# The name infomation recieved is: turukhansk
# The name infomation recieved is: pontianak
# The name infomation recieved is: meilu
# no city data
# The name infomation recieved is: atuona
# The name infomation recieved is: port elizabeth
# The name infomation recieved is: poronaysk
# The name infomation recieved is: punta arenas
# The name infomation recieved is: barrow
# The name infomation recieved is: sibolga
# The name infomation recieved is: vydrino
# The name infomation recieved is: vardo
# The name infomation recieved is: portland
# The name infomation recieved is: storm lake
# The name infomation recieved is: cabo san lucas
# The name infomation recieved is: east london
# The name infomation recieved is: faanui
# The name infomation recieved is: zharkovskiy
# The name infomation recieved is: pochutla
# The name infomation recieved is: tiksi
# The name infomation recieved is: mys shmidta
# no city data
# The name infomation recieved is: daru
# The name infomation recieved is: new norfolk
# The name infomation recieved is: tumannyy
# no city data
# The name infomation recieved is: shaowu
# The name infomation recieved is: makakilo city
# The name infomation recieved is: ismailia
# The name infomation recieved is: viligili
# no city data
# The name infomation recieved is: cockburn town
# The name infomation recieved is: afanasyevo
# no city data
# The name infomation recieved is: taolanaro
# no city data
# The name infomation recieved is: butaritari
# The name infomation recieved is: pemba
# The name infomation recieved is: barawe
# no city data
# The name infomation recieved is: chokurdakh
# The name infomation recieved is: kodiak
# The name infomation recieved is: fairbanks
# The name infomation recieved is: jamestown
# The name infomation recieved is: port lincoln
# The name infomation recieved is: port alfred
# The name infomation recieved is: saint-francois
# The name infomation recieved is: kurilsk
# The name infomation recieved is: hilo
# The name infomation recieved is: qaanaaq
# The name infomation recieved is: cayenne
# The name infomation recieved is: safwah
# no city data
# The name infomation recieved is: cherskiy
# The name infomation recieved is: belushya guba
# no city data
# The name infomation recieved is: amderma
# no city data
# The name infomation recieved is: dum duma
# The name infomation recieved is: porto velho
# The name infomation recieved is: newport
# The name infomation recieved is: komsomolskiy
# The name infomation recieved is: uarini
# The name infomation recieved is: camacha
# The name infomation recieved is: albany
# The name infomation recieved is: santa cruz
# The name infomation recieved is: tuatapere
# The name infomation recieved is: ponta do sol
# The name infomation recieved is: castro
# The name infomation recieved is: eufaula
# The name infomation recieved is: geraldton
# The name infomation recieved is: georgetown
# The name infomation recieved is: rawannawi
# no city data
# The name infomation recieved is: saskylakh
# The name infomation recieved is: hobart
# The name infomation recieved is: illoqqortoormiut
# no city data
# The name infomation recieved is: knysna
# The name infomation recieved is: esperance
# The name infomation recieved is: puerto ayora
# The name infomation recieved is: kapaa
# The name infomation recieved is: west wendover
# The name infomation recieved is: bredasdorp
# The name infomation recieved is: bluff
# The name infomation recieved is: upernavik
# The name infomation recieved is: puerto suarez
# The name infomation recieved is: ahipara
# The name infomation recieved is: bambous virieux
# The name infomation recieved is: adzope
# The name infomation recieved is: praia da vitoria
# The name infomation recieved is: lavrentiya
# The name infomation recieved is: farsund
# The name infomation recieved is: faya
# The name infomation recieved is: mokobeng
# The name infomation recieved is: utiroa
# no city data
# The name infomation recieved is: arinos
# The name infomation recieved is: whitehorse
# The name infomation recieved is: kuche
# no city data
# The name infomation recieved is: barentsburg
# no city data
# The name infomation recieved is: port macquarie
# The name infomation recieved is: hasaki
# The name infomation recieved is: saint-philippe
# The name infomation recieved is: illela
# The name infomation recieved is: cape town
# The name infomation recieved is: norman wells
# The name infomation recieved is: fortuna
# The name infomation recieved is: luderitz
# The name infomation recieved is: korla
# The name infomation recieved is: rawson
# The name infomation recieved is: tekeli
# The name infomation recieved is: airai
# The name infomation recieved is: chilia veche
# The name infomation recieved is: kidal
# The name infomation recieved is: kaitangata
# The name infomation recieved is: hermanus
# The name infomation recieved is: vaini
# The name infomation recieved is: naze
# The name infomation recieved is: constitucion
# The name infomation recieved is: ribeira grande
# The name infomation recieved is: talnakh
# The name infomation recieved is: thomasville
# The name infomation recieved is: flin flon
# The name infomation recieved is: petropavlovsk-kamchatskiy
# The name infomation recieved is: palmer
# The name infomation recieved is: ketchikan
# The name infomation recieved is: mar del plata
# The name infomation recieved is: kiama
# The name infomation recieved is: attawapiskat
# no city data
# The name infomation recieved is: pirovskoye
# The name infomation recieved is: acari
# The name infomation recieved is: pitkyaranta
# The name infomation recieved is: sawakin
# The name infomation recieved is: shizuishan
# The name infomation recieved is: paysandu
# The name infomation recieved is: bengkulu
# The name infomation recieved is: mao
# The name infomation recieved is: dali
# The name infomation recieved is: tura
# The name infomation recieved is: vaitape
# The name infomation recieved is: yar-sale
# The name infomation recieved is: iqaluit
# The name infomation recieved is: samusu
# no city data
# The name infomation recieved is: saint george
# The name infomation recieved is: quatre cocos
# The name infomation recieved is: suez
# The name infomation recieved is: marsabit
# The name infomation recieved is: tasiilaq
# The name infomation recieved is: concordia
# The name infomation recieved is: deputatskiy
# The name infomation recieved is: riyadh
# The name infomation recieved is: qorveh
# The name infomation recieved is: touros
# The name infomation recieved is: gorom-gorom
# The name infomation recieved is: plettenberg bay
# The name infomation recieved is: nizhneyansk
# no city data
# The name infomation recieved is: hithadhoo
# The name infomation recieved is: thompson
# The name infomation recieved is: russell
# The name infomation recieved is: sur
# The name infomation recieved is: leningradskiy
# The name infomation recieved is: bisira
# The name infomation recieved is: nome
# The name infomation recieved is: kamenskoye
# no city data
# The name infomation recieved is: henties bay
# The name infomation recieved is: aporawan
# no city data
# The name infomation recieved is: bose
# The name infomation recieved is: udachnyy
# The name infomation recieved is: sinnamary
# The name infomation recieved is: yellowknife
# The name infomation recieved is: sao filipe
# The name infomation recieved is: namatanai
# The name infomation recieved is: civitavecchia
# The name infomation recieved is: chingirlau
# The name infomation recieved is: grand gaube
# The name infomation recieved is: mataura
# The name infomation recieved is: sibiti
# The name infomation recieved is: bathsheba
# The name infomation recieved is: moerai
# The name infomation recieved is: ancud
# The name infomation recieved is: kalangala
# The name infomation recieved is: namibe
# The name infomation recieved is: bela vista
# The name infomation recieved is: nemuro
# The name infomation recieved is: bac lieu
# The name infomation recieved is: mahebourg
# The name infomation recieved is: boende
# The name infomation recieved is: bandarbeyla
# The name infomation recieved is: avarua
# The name infomation recieved is: coquimbo
# The name infomation recieved is: chuy
# The name infomation recieved is: bajo baudo
# no city data
# The name infomation recieved is: bilma
# The name infomation recieved is: sao francisco de assis
# The name infomation recieved is: haines junction
# The name infomation recieved is: fukue
# The name infomation recieved is: marzuq
# The name infomation recieved is: flinders
# The name infomation recieved is: carnarvon
# The name infomation recieved is: zhangjiakou
# The name infomation recieved is: ondangwa
# The name infomation recieved is: caravelas
# The name infomation recieved is: souillac
# The name infomation recieved is: kozhevnikovo
# The name infomation recieved is: ryotsu
# The name infomation recieved is: pevek
# The name infomation recieved is: verkhoshizhemye
# The name infomation recieved is: kabalo
# The name infomation recieved is: kysyl-syr
# The name infomation recieved is: mezen
# The name infomation recieved is: bud
# The name infomation recieved is: yasnyy
# The name infomation recieved is: high level
# The name infomation recieved is: nantucket
# The name infomation recieved is: choix
# The name infomation recieved is: severobaykalsk
# The name infomation recieved is: codrington
# The name infomation recieved is: oranjemund
# The name infomation recieved is: honiara
# The name infomation recieved is: mugla
# The name infomation recieved is: doka
# The name infomation recieved is: sentyabrskiy
# no city data
# The name infomation recieved is: margate
# The name infomation recieved is: burica
# no city data
# The name infomation recieved is: lompoc
# The name infomation recieved is: przhevalskoye
# The name infomation recieved is: naryan-mar
# The name infomation recieved is: tuktoyaktuk
# The name infomation recieved is: les cayes
# The name infomation recieved is: uklana mandi
# The name infomation recieved is: store heddinge
# The name infomation recieved is: hanna
# The name infomation recieved is: jiaojiang
# The name infomation recieved is: hanmer springs
# The name infomation recieved is: ous
# The name infomation recieved is: christchurch
# The name infomation recieved is: kumluca
# The name infomation recieved is: sovkhoznyy
# The name infomation recieved is: lisakovsk
# The name infomation recieved is: atbasar
# The name infomation recieved is: rio cuarto
# The name infomation recieved is: moron
# The name infomation recieved is: victoria
# The name infomation recieved is: arraial do cabo
# The name infomation recieved is: mildura
# The name infomation recieved is: jabiru
# no city data
# The name infomation recieved is: bubaque
# The name infomation recieved is: yatou
# The name infomation recieved is: lamont
# The name infomation recieved is: sinkat
# no city data
# The name infomation recieved is: onega
# The name infomation recieved is: luwuk
# The name infomation recieved is: kahului
# The name infomation recieved is: formoso do araguaia
# no city data
# The name infomation recieved is: dikson
# The name infomation recieved is: grindavik
# The name infomation recieved is: seoul
# The name infomation recieved is: urumqi
# The name infomation recieved is: igrim
# The name infomation recieved is: longyearbyen
# The name infomation recieved is: tsihombe
# no city data
# The name infomation recieved is: kavieng
# The name infomation recieved is: male
# The name infomation recieved is: aripuana
# The name infomation recieved is: paamiut
# The name infomation recieved is: waingapu
# The name infomation recieved is: presidencia roque saenz pena
# The name infomation recieved is: laguna
# The name infomation recieved is: chicama
# The name infomation recieved is: strezhevoy
# The name infomation recieved is: muros
# The name infomation recieved is: vestmannaeyjar
# The name infomation recieved is: halalo
# no city data
# The name infomation recieved is: saleaula
# no city data
# The name infomation recieved is: torbay
# The name infomation recieved is: srednekolymsk
# The name infomation recieved is: ngunguru
# The name infomation recieved is: la ronge
# The name infomation recieved is: bethel
# The name infomation recieved is: shimanovsk
# The name infomation recieved is: normandin
# The name infomation recieved is: avera
# The name infomation recieved is: taoudenni
# The name infomation recieved is: harper
# The name infomation recieved is: taungdwingyi
# The name infomation recieved is: fort walton beach
# The name infomation recieved is: wattegama
# The name infomation recieved is: beni
# The name infomation recieved is: nikolskoye
# The name infomation recieved is: vila franca do campo
# The name infomation recieved is: alice springs
# The name infomation recieved is: vila
# The name infomation recieved is: cordoba
# The name infomation recieved is: ekhabi
# The name infomation recieved is: kishtwar
# The name infomation recieved is: kabwe
# The name infomation recieved is: show low
# The name infomation recieved is: taltal
# The name infomation recieved is: fresnillo
# The name infomation recieved is: guines
# The name infomation recieved is: narsaq
# The name infomation recieved is: pitimbu
# The name infomation recieved is: palmas bellas
# The name infomation recieved is: fairfield
# The name infomation recieved is: verkh-chebula
# The name infomation recieved is: la palma
# The name infomation recieved is: kamloops
# The name infomation recieved is: bani
# The name infomation recieved is: mayo
# The name infomation recieved is: wamba
# The name infomation recieved is: hede
# The name infomation recieved is: olinda
# The name infomation recieved is: rocha
# The name infomation recieved is: agva
# no city data
# The name infomation recieved is: olafsvik
# The name infomation recieved is: neuquen
# The name infomation recieved is: emerald
# The name infomation recieved is: broome
# The name infomation recieved is: karpathos
# The name infomation recieved is: sabinas
# The name infomation recieved is: salalah
# The name infomation recieved is: sfantu gheorghe
# The name infomation recieved is: bras-panon
# The name infomation recieved is: manggar
# The name infomation recieved is: prince rupert
# The name infomation recieved is: altamont
# The name infomation recieved is: lemesos
# no city data
# The name infomation recieved is: asmara
# The name infomation recieved is: lokoja
# The name infomation recieved is: teya
# The name infomation recieved is: klaksvik
# The name infomation recieved is: sarangani
# The name infomation recieved is: sarreguemines
# The name infomation recieved is: eyl
# The name infomation recieved is: bairiki
# The name infomation recieved is: kodinsk
# The name infomation recieved is: challans
# The name infomation recieved is: jinxi
# The name infomation recieved is: saint anthony
# The name infomation recieved is: banepa
# The name infomation recieved is: aljezur
# The name infomation recieved is: turtas
# The name infomation recieved is: deori
# The name infomation recieved is: gidam
# The name infomation recieved is: walvis bay
# The name infomation recieved is: parakai
# The name infomation recieved is: kesinga
# The name infomation recieved is: burnie
# The name infomation recieved is: benito juarez
# The name infomation recieved is: bobonong
# no city data
# The name infomation recieved is: kavaratti
# The name infomation recieved is: yuli
# The name infomation recieved is: grafton
# The name infomation recieved is: corner brook
# The name infomation recieved is: dera bugti
# The name infomation recieved is: gussago
# The name infomation recieved is: lagoa
# The name infomation recieved is: wasilla
# The name infomation recieved is: kupang
# The name infomation recieved is: grajewo
# The name infomation recieved is: kazalinsk
# no city data
# The name infomation recieved is: adrar
# The name infomation recieved is: kochki
# The name infomation recieved is: narsipatnam
# The name infomation recieved is: hualmay
# The name infomation recieved is: pareora
# The name infomation recieved is: clyde river
# The name infomation recieved is: barbastro
# The name infomation recieved is: moberly
# The name infomation recieved is: lorengau
# The name infomation recieved is: biak
# The name infomation recieved is: maniitsoq
# The name infomation recieved is: zhangye
# The name infomation recieved is: maragogi
# The name infomation recieved is: isla mujeres
# The name infomation recieved is: nuuk
# The name infomation recieved is: conde
# The name infomation recieved is: khatanga
# The name infomation recieved is: mitsamiouli
# The name infomation recieved is: cabras
# The name infomation recieved is: saldanha
# The name infomation recieved is: sudislavl
# The name infomation recieved is: gigmoto
# The name infomation recieved is: guarapari
# The name infomation recieved is: glotovka
# The name infomation recieved is: oppdal
# The name infomation recieved is: road town
# The name infomation recieved is: el alto
# The name infomation recieved is: bethanien
# The name infomation recieved is: turiacu
# The name infomation recieved is: sitka
# The name infomation recieved is: nhulunbuy
# The name infomation recieved is: nguruka
# The name infomation recieved is: taree
# The name infomation recieved is: verkhnyaya sysert
# The name infomation recieved is: cumaribo
# no city data
# The name infomation recieved is: coxim
# The name infomation recieved is: alyangula
# The name infomation recieved is: husavik
# The name infomation recieved is: zhezkazgan
# The name infomation recieved is: camacupa
# The name infomation recieved is: mount gambier
# The name infomation recieved is: san ramon
# The name infomation recieved is: farmersville
# The name infomation recieved is: la paz centro
# The name infomation recieved is: grand river south east
# no city data
# The name infomation recieved is: marcona
# no city data
# The name infomation recieved is: golubitskaya
# The name infomation recieved is: oktyabrskoye
# The name infomation recieved is: vao
# The name infomation recieved is: rancho cucamonga
# The name infomation recieved is: severo-kurilsk
# The name infomation recieved is: crab hill
# no city data
# The name infomation recieved is: umm lajj
# The name infomation recieved is: viedma
# The name infomation recieved is: acapulco
# The name infomation recieved is: brainerd
# The name infomation recieved is: vaitupu
# no city data
# The name infomation recieved is: caceres
# The name infomation recieved is: dukat
# The name infomation recieved is: turbat
# The name infomation recieved is: beloha
# The name infomation recieved is: pekalongan
# The name infomation recieved is: tabou
# The name infomation recieved is: muravlenko
# The name infomation recieved is: palabuhanratu
# no city data
# The name infomation recieved is: yulara
# The name infomation recieved is: matara
# The name infomation recieved is: omboue
# The name infomation recieved is: college
# The name infomation recieved is: svetlaya
# The name infomation recieved is: lazaro cardenas
# The name infomation recieved is: los llanos de aridane
# The name infomation recieved is: acajutla
# The name infomation recieved is: mehtar lam
# The name infomation recieved is: kracheh
# no city data
# The name infomation recieved is: lundamo
# The name infomation recieved is: shubarshi
# The name infomation recieved is: sao joao da barra
# The name infomation recieved is: australind
# The name infomation recieved is: tiznit
# The name infomation recieved is: umba
# The name infomation recieved is: van
# The name infomation recieved is: bafia
# The name infomation recieved is: san quintin
# The name infomation recieved is: arlit
# The name infomation recieved is: yorosso
# The name infomation recieved is: hambantota
# The name infomation recieved is: vostok
# The name infomation recieved is: awjilah
# The name infomation recieved is: campo grande
# The name infomation recieved is: provideniya
# The name infomation recieved is: liku
# The name infomation recieved is: san cristobal
# The name infomation recieved is: ankang
# The name infomation recieved is: villa de reyes
# The name infomation recieved is: mannarakkat
# The name infomation recieved is: vila velha
# The name infomation recieved is: galle
# The name infomation recieved is: ilhabela
# The name infomation recieved is: sorland
# The name infomation recieved is: bonavista
# The name infomation recieved is: aswan
# The name infomation recieved is: sisophon
# The name infomation recieved is: lolua
# no city data
# The name infomation recieved is: san ignacio
# The name infomation recieved is: saint-donat-de-montcalm
# The name infomation recieved is: krasnaya gora
# The name infomation recieved is: lata
# The name infomation recieved is: timizart
# The name infomation recieved is: we
# no city data
# The name infomation recieved is: brae
# The name infomation recieved is: sioux lookout
# The name infomation recieved is: bodden town
# The name infomation recieved is: mwene-ditu
# The name infomation recieved is: redcar
# The name infomation recieved is: leh
# The name infomation recieved is: kirakira
# The name infomation recieved is: gornopravdinsk
# The name infomation recieved is: batagay-alyta
# The name infomation recieved is: obo
# The name infomation recieved is: tomatlan
# The name infomation recieved is: ogbomosho
# The name infomation recieved is: soto la marina
# The name infomation recieved is: mchinji
# The name infomation recieved is: aklavik
# The name infomation recieved is: makaha
# The name infomation recieved is: douentza
# The name infomation recieved is: kruisfontein
# The name infomation recieved is: alihe
# The name infomation recieved is: alamosa
# The name infomation recieved is: ardistan
# no city data
# The name infomation recieved is: beringovskiy
# The name infomation recieved is: grand-santi
# The name infomation recieved is: port moresby
# The name infomation recieved is: ust-nera
# The name infomation recieved is: impfondo
# The name infomation recieved is: bolungarvik
# no city data
# The name infomation recieved is: nandura
# The name infomation recieved is: buchanan
# The name infomation recieved is: copiapo
# The name infomation recieved is: sorvag
# no city data
# The name infomation recieved is: saint-augustin
# The name infomation recieved is: mabaruma
# The name infomation recieved is: kandi
# The name infomation recieved is: inverness
# The name infomation recieved is: mecca
# The name infomation recieved is: vagay
# The name infomation recieved is: colon
# The name infomation recieved is: killybegs
# The name infomation recieved is: garowe
# The name infomation recieved is: kalmunai
# The name infomation recieved is: coahuayana
# The name infomation recieved is: anadyr
# The name infomation recieved is: am timan
# The name infomation recieved is: karaul
# no city data
# The name infomation recieved is: tuggurt
# no city data
# The name infomation recieved is: dingle
# The name infomation recieved is: prado
# The name infomation recieved is: rio grande
# The name infomation recieved is: dossor
# The name infomation recieved is: panacan
# The name infomation recieved is: rio gallegos
# The name infomation recieved is: ust-maya
# The name infomation recieved is: sakakah
# The name infomation recieved is: ostrovnoy
# The name infomation recieved is: nouadhibou
# The name infomation recieved is: saint-pierre
# The name infomation recieved is: kudahuvadhoo
# The name infomation recieved is: bardiyah
# The name infomation recieved is: doctor pedro p. pena
# no city data
# The name infomation recieved is: qaqortoq
# The name infomation recieved is: cape coast
# The name infomation recieved is: sistranda
# The name infomation recieved is: nioro
# The name infomation recieved is: chapais
# The name infomation recieved is: darovskoy
# The name infomation recieved is: shimoda
# The name infomation recieved is: ust-ilimsk
# The name infomation recieved is: yunhe
# The name infomation recieved is: rapar
# The name infomation recieved is: mackay
# The name infomation recieved is: manzil tamim
# no city data
# The name infomation recieved is: yining
# The name infomation recieved is: itarema
# The name infomation recieved is: gzhatsk
# no city data
# The name infomation recieved is: sola
# The name infomation recieved is: nechi
# The name infomation recieved is: kyshtovka
# The name infomation recieved is: maloshuyka
# no city data
# The name infomation recieved is: notse
# The name infomation recieved is: tanauan
# The name infomation recieved is: chara
# The name infomation recieved is: ullapool
# The name infomation recieved is: tecpatan
# The name infomation recieved is: tamiahua
# The name infomation recieved is: rohatyn
# The name infomation recieved is: celestun
# The name infomation recieved is: rafraf
# The name infomation recieved is: auki
# The name infomation recieved is: jaciara
# The name infomation recieved is: upington
# The name infomation recieved is: armacao dos buzios
# no city data
# The name infomation recieved is: xiongzhou
# The name infomation recieved is: meyungs
# no city data
# The name infomation recieved is: bereda
# The name infomation recieved is: abu zabad
# The name infomation recieved is: necochea
# The name infomation recieved is: port-cartier
# The name infomation recieved is: kjollefjord
# The name infomation recieved is: san andres
# The name infomation recieved is: nicoya
# The name infomation recieved is: powell river
# The name infomation recieved is: isangel
# The name infomation recieved is: tevaitoa
# The name infomation recieved is: coffeyville
# The name infomation recieved is: russkaya polyana
# The name infomation recieved is: suntar
# The name infomation recieved is: sauda
# The name infomation recieved is: seabra
# The name infomation recieved is: palanga
# The name infomation recieved is: zhanaozen
# The name infomation recieved is: san joaquin
# The name infomation recieved is: longlac
# no city data
# The name infomation recieved is: tosno
# The name infomation recieved is: alta floresta
# The name infomation recieved is: ahuimanu
# The name infomation recieved is: manono
# The name infomation recieved is: amahai
# The name infomation recieved is: naranjal
# The name infomation recieved is: ayr
# The name infomation recieved is: mersing
# The name infomation recieved is: mahibadhoo
# The name infomation recieved is: barcelona
# The name infomation recieved is: westport
# The name infomation recieved is: iralaya
# The name infomation recieved is: akom
# The name infomation recieved is: krasnoborsk
# The name infomation recieved is: samana
# The name infomation recieved is: altay
# The name infomation recieved is: marsa matruh
# The name infomation recieved is: phitsanulok
# The name infomation recieved is: lodja
# The name infomation recieved is: gouyave
# The name infomation recieved is: gamba
# The name infomation recieved is: nylstroom
# no city data
# The name infomation recieved is: mangochi
# The name infomation recieved is: surt
# The name infomation recieved is: comodoro rivadavia
# The name infomation recieved is: susanino
# The name infomation recieved is: campbell river

# %%
cities_dict = {
    "City": name,
    "Lat": lat, 
    "Long": long, 
    "Max Temp": temp_max,
    "Humidity": humidity,
    "Cloudiness": cloudiness, 
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date}
    
cities_df = pd.DataFrame(cities_dict)     

cities_df
# Out:
#                    City    Lat    Long  Max Temp  Humidity  Cloudiness  \
# 0              Cidreira -30.18  -50.21     15.16        74           0
# 1                  Lebu -37.62  -73.65     11.18        93          28
# 2               Rikitea -23.12 -134.97     23.29        77          11
# 3              Coihueco -36.62  -71.83     12.78       100          75
# 4               Ushuaia -54.80  -68.30      6.00        75          40
# ..                  ...    ...     ...       ...       ...         ...
# 546            Mangochi -14.48   35.26     16.50        80          24
# 547               Sirte  31.21   16.59     25.42        81           0
# 548  Comodoro Rivadavia -45.87  -67.50     15.00        38         100
# 549            Susanino  58.15   41.59     10.60        96           8
# 550      Campbell River  50.02 -125.24     24.00        47          75
#
#      Wind Speed Country        Date
# 0          3.32      BR  1596319681
# 1          3.51      CL  1596319681
# 2          3.64      PF  1596319682
# 3          6.70      CL  1596319682
# 4          2.10      AR  1596319613
# ..          ...     ...         ...
# 546        2.84      MW  1596319815
# 547        1.36      LY  1596319815
# 548       15.40      AR  1596319816
# 549        3.63      RU  1596319816
# 550        4.60      CA  1596319816
#
# [551 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.dtypes
# Out:
# City           object
# Lat           float64
# Long          float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_df[cities_df.Humidity >100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Long, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = cities_df

# %%
# Export the City_Data into a csv

clean_city_data.to_csv('clean city data', header=True, index=False)

# %%
cities  = pd.read_csv('clean city data')
cities
# Out:
#                    City    Lat    Long  Max Temp  Humidity  Cloudiness  \
# 0              Cidreira -30.18  -50.21     15.16        74           0
# 1                  Lebu -37.62  -73.65     11.18        93          28
# 2               Rikitea -23.12 -134.97     23.29        77          11
# 3              Coihueco -36.62  -71.83     12.78       100          75
# 4               Ushuaia -54.80  -68.30      6.00        75          40
# ..                  ...    ...     ...       ...       ...         ...
# 546            Mangochi -14.48   35.26     16.50        80          24
# 547               Sirte  31.21   16.59     25.42        81           0
# 548  Comodoro Rivadavia -45.87  -67.50     15.00        38         100
# 549            Susanino  58.15   41.59     10.60        96           8
# 550      Campbell River  50.02 -125.24     24.00        47          75
#
#      Wind Speed Country        Date
# 0          3.32      BR  1596319681
# 1          3.51      CL  1596319681
# 2          3.64      PF  1596319682
# 3          6.70      CL  1596319682
# 4          2.10      AR  1596319613
# ..          ...     ...         ...
# 546        2.84      MW  1596319815
# 547        1.36      LY  1596319815
# 548       15.40      AR  1596319816
# 549        3.63      RU  1596319816
# 550        4.60      CA  1596319816
#
# [551 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Creat a Scatter Plot for temperature vs humidity

plt.figure(figsize=(9,5))
x_values = cities["Lat"]
y_values = cities["Humidity"]
plt.scatter(x_values,y_values)
plt.title("City Latitude vs. Humidity (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Humidity (%)", fontdict={"fontsize": 12})
plt.savefig('latitude_vs_humidity.png', dpi=300)
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(9,5))
x_values = cities["Lat"]
y_values = cities["Cloudiness"]
plt.scatter(x_values,y_values)
plt.title("City Latitude vs. Cloudiness (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Cloudiness (%)", fontdict={"fontsize": 12})
plt.savefig('latitude_vs_cloudiness.png', dpi=300)
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(9,5))
x_values = cities["Lat"]
y_values = cities["Wind Speed"]
plt.scatter(x_values,y_values)
plt.title("City Latitude vs. Wind Speed (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Wind Speed (m/s)", fontdict={"fontsize": 12})
plt.savefig('latitude_vs_wind_speed.png', dpi=300)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hem = cities.loc[cities['Lat']>0]
north_hem.head(3)
# Out:
#            City    Lat    Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 6   Kloulklubed   7.04  134.26     25.00        94          75        1.50
# 7    Turukhansk  65.82   87.98     12.33        71           8        3.06
# 11    Poronaysk  49.22  143.12     15.74        95          93        5.79
#
#    Country        Date
# 6       PW  1596319683
# 7       RU  1596319683
# 11      RU  1596319684

# %%
south_hem = cities.loc[cities['Lat']<0]
south_hem.head(3)
# Out:
#        City    Lat    Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Cidreira -30.18  -50.21     15.16        74           0        3.32
# 1      Lebu -37.62  -73.65     11.18        93          28        3.51
# 2   Rikitea -23.12 -134.97     23.29        77          11        3.64
#
#   Country        Date
# 0      BR  1596319681
# 1      CL  1596319681
# 2      PF  1596319682

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.figure(figsize=(9,5))
x_values = north_hem["Lat"]
y_values = north_hem["Max Temp"]
plt.scatter(x_values,y_values)
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Max Temperature ˚C", fontdict={"fontsize": 12})


# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(10,10),fontsize=15,color="red")

# Print r square value

print(f"The r-squared is: {rvalue**2}")
plt.savefig('northern_hemisphere_regression.png', dpi=300)
plt.show()
# Out:
# The r-squared is: 0.4491072957472998

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.figure(figsize=(9,5))
x_values = south_hem["Lat"]
y_values = south_hem["Max Temp"]
plt.scatter(x_values,y_values)
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Max Temperature ˚C", fontdict={"fontsize": 12})

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")

# Print r square value

print(f"The r-squared is: {rvalue**2}")
plt.savefig('Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png', dpi=300)
plt.show()
# Out:
# The r-squared is: 0.566053421540612

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(9,5))
x_values = north_hem["Lat"]
y_values = north_hem["Humidity"]
plt.scatter(x_values,y_values)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Humidity (%)", fontdict={"fontsize": 12})

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(50,10),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.savefig('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png', dpi=300)
plt.show()
# Out:
# The r-squared is: 7.598554625788892e-07

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(9,5))
x_values = south_hem["Lat"]
y_values = south_hem["Humidity"]
plt.scatter(x_values,y_values)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Humidity", fontdict={"fontsize": 12})

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")

# Print r square value

print(f"The r-squared is: {rvalue**2}")
plt.savefig('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png', dpi=300)
plt.show()
# Out:
# The r-squared is: 0.006842568120351306

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(9,5))
x_values = north_hem["Lat"]
y_values = north_hem["Cloudiness"]
plt.scatter(x_values,y_values)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Coudiness (%)", fontdict={"fontsize": 12})

# Perform a linear regression 
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.plot(x_values,regress_values,"r-")

plt.annotate(line_eq,(50,10),fontsize=15,color="red")

print(f"The r-squared is: {rvalue**2}")

plt.savefig('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png', dpi=300)
plt.show()
# Out:
# The r-squared is: 4.803002738727149e-05

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(9,5))
x_values = south_hem["Lat"]
y_values = south_hem["Cloudiness"]
plt.scatter(x_values,y_values)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Cloudiness (%)", fontdict={"fontsize": 12})

# Perform a linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-55,32),fontsize=15,color="red")

# Print r square value

print(f"The r-squared is: {rvalue**2}")
plt.savefig('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png', dpi=300)
plt.show()
# Out:
# The r-squared is: 0.004482725206810711

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (m/s) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(9,5))
x_values = north_hem["Lat"]
y_values = north_hem["Wind Speed"]
plt.scatter(x_values,y_values)
plt.title("Northern Hemisphere - Wind Speed (m/s) vs. Latitude Linear Regression(08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Wind Speed (m/s)", fontdict={"fontsize": 12})

# Perform a linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(50,11),fontsize=15,color="red")

# Print r square value
print(f"The r-squared is: {rvalue**2}")

plt.savefig('Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png', dpi=300)
plt.show()
# Out:
# The r-squared is: 0.010439244574587543

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (m/s) vs. Latitude Linear Regression

# %%
plt.figure(figsize=(9,5))
x_values = south_hem["Lat"]
y_values = south_hem["Wind Speed"]
plt.scatter(x_values,y_values)
plt.title("Southern Hemisphere - Wind Speed (m/s) vs. Latitude Linear Regression (08/01/2020)", fontdict={"fontweight":"bold", "fontsize": 14})
plt.xlabel("Latitude", fontdict={"fontsize": 12})
plt.ylabel("Wind Speed (m/s)", fontdict={"fontsize": 12})

# Perform a linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")

# Print r square value

print(f"The r-squared is: {rvalue**2}")
plt.savefig('Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png', dpi=300)
plt.show()
# Out:
# The r-squared is: 0.0007019109881283263
